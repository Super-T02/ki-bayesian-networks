# %% [markdown]
# # Probabilistic Network for the grades of Portugiese students

# %%
# !python -m venv ../.env
# !source ../.env/bin/activate
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: asttokens==2.2.1 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: backcall==0.2.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: bnlearn==0.7.14 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 3)) (0.7.14)
# Requirement already satisfied: certifi==2022.12.7 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 4)) (2022.12.7)
# Requirement already satisfied: charset-normalizer==3.1.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: click==8.1.3 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 6)) (8.1.3)
# Requirement already satisfied: cmake==3.26.1 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 7)) (3.26.1)
# Requirement already satisfied: comm==0.1.3 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 8)) (0.1.3)
# Requirement already satisfied: contourpy==1.0.7 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 9)) (1.0.7)
# Requirement already satisfied: cycler==0.11.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 10)) (0.11.0)
# Requirement already satisfied: debugpy==1.6.6 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 11)) (1.6.6)
# Requirement already satisfied: decorator==5.1.1 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 12)) (5.1.1)
# Requirement already satisfied: df2onehot==1.0.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 13)) (1.0.2)
# Requirement already satisfied: executing==1.2.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 14)) (1.2.0)
# Requirement already satisfied: filelock==3.10.7 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 15)) (3.10.7)
# Requirement already satisfied: fonttools==4.39.3 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 16)) (4.39.3)
# Requirement already satisfied: fsspec==2023.3.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 17)) (2023.3.0)
# Requirement already satisfied: funcsigs==1.0.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 18)) (1.0.2)
# Requirement already satisfied: idna==3.4 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 19)) (3.4)
# Requirement already satisfied: ipykernel==6.22.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 20)) (6.22.0)
# Requirement already satisfied: ipython==8.12.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 21)) (8.12.0)
# Requirement already satisfied: ipywidgets==8.0.6 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 22)) (8.0.6)
# Requirement already satisfied: ismember==1.0.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 23)) (1.0.2)
# Requirement already satisfied: jedi==0.18.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 24)) (0.18.2)
# Requirement already satisfied: Jinja2==3.1.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 25)) (3.1.2)
# Requirement already satisfied: joblib==1.2.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 26)) (1.2.0)
# Requirement already satisfied: jsonpickle==3.0.1 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 27)) (3.0.1)
# Requirement already satisfied: jupyter_client==8.1.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 28)) (8.1.0)
# Requirement already satisfied: jupyter_core==5.3.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 29)) (5.3.0)
# Requirement already satisfied: jupyterlab-widgets==3.0.7 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 30)) (3.0.7)
# Requirement already satisfied: kiwisolver==1.4.4 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 31)) (1.4.4)
# Requirement already satisfied: lit==16.0.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 32)) (16.0.0)
# Requirement already satisfied: MarkupSafe==2.1.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 33)) (2.1.2)
# Requirement already satisfied: matplotlib==3.7.1 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 34)) (3.7.1)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 35)) (0.1.6)
# Requirement already satisfied: mpmath==1.3.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 36)) (1.3.0)
# Requirement already satisfied: nest-asyncio==1.5.6 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 37)) (1.5.6)
# Requirement already satisfied: networkx==3.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 38)) (3.0)
# Requirement already satisfied: numpy==1.24.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 39)) (1.24.2)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 40)) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 41)) (11.7.101)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 42)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 43)) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 44)) (8.5.0.96)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 45)) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 46)) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 47)) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 48)) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 49)) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 50)) (11.7.91)
# Requirement already satisfied: opt-einsum==3.3.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 51)) (3.3.0)
# Requirement already satisfied: packaging==23.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 52)) (23.0)
# Requirement already satisfied: pandas==1.5.3 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 53)) (1.5.3)
# Requirement already satisfied: parso==0.8.3 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 54)) (0.8.3)
# Requirement already satisfied: patsy==0.5.3 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 55)) (0.5.3)
# Requirement already satisfied: pexpect==4.8.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 56)) (4.8.0)
# Requirement already satisfied: pgmpy==0.1.21 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 57)) (0.1.21)
# Requirement already satisfied: pickleshare==0.7.5 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 58)) (0.7.5)
# Requirement already satisfied: Pillow==9.5.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 59)) (9.5.0)
# Requirement already satisfied: platformdirs==3.2.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 60)) (3.2.0)
# Requirement already satisfied: prompt-toolkit==3.0.38 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 61)) (3.0.38)
# Requirement already satisfied: psutil==5.9.4 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 62)) (5.9.4)
# Requirement already satisfied: ptyprocess==0.7.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 63)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 64)) (0.2.2)
# Requirement already satisfied: Pygments==2.14.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 65)) (2.14.0)
# Requirement already satisfied: pyparsing==3.0.9 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 66)) (3.0.9)
# Requirement already satisfied: pypickle==1.1.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 67)) (1.1.0)
# Requirement already satisfied: python-dateutil==2.8.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 68)) (2.8.2)
# Requirement already satisfied: python-louvain==0.16 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 69)) (0.16)
# Requirement already satisfied: pytz==2023.3 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 70)) (2023.3)
# Requirement already satisfied: pyvis==0.3.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 71)) (0.3.2)
# Requirement already satisfied: pyzmq==25.0.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 72)) (25.0.2)
# Requirement already satisfied: requests==2.28.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 73)) (2.28.2)
# Requirement already satisfied: scikit-learn==1.2.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 74)) (1.2.2)
# Requirement already satisfied: scipy==1.10.1 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 75)) (1.10.1)
# Requirement already satisfied: seaborn==0.12.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 76)) (0.12.2)
# Requirement already satisfied: six==1.16.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 77)) (1.16.0)
# Requirement already satisfied: stack-data==0.6.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 78)) (0.6.2)
# Requirement already satisfied: statsmodels==0.13.5 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 79)) (0.13.5)
# Requirement already satisfied: sympy==1.11.1 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 80)) (1.11.1)
# Requirement already satisfied: tabulate==0.9.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 81)) (0.9.0)
# Requirement already satisfied: threadpoolctl==3.1.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 82)) (3.1.0)
# Requirement already satisfied: tk==0.1.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 83)) (0.1.0)
# Requirement already satisfied: torch==2.0.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 84)) (2.0.0)
# Requirement already satisfied: tornado==6.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 85)) (6.2)
# Requirement already satisfied: tqdm==4.65.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 86)) (4.65.0)
# Requirement already satisfied: traitlets==5.9.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 87)) (5.9.0)
# Requirement already satisfied: triton==2.0.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 88)) (2.0.0)
# Requirement already satisfied: typing_extensions==4.5.0 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 89)) (4.5.0)
# Requirement already satisfied: urllib3==1.26.15 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 90)) (1.26.15)
# Requirement already satisfied: wcwidth==0.2.6 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 91)) (0.2.6)
# Requirement already satisfied: wget==3.2 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 92)) (3.2)
# Requirement already satisfied: widgetsnbextension==4.0.7 in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 93)) (4.0.7)
# Requirement already satisfied: setuptools in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->-r ../requirements.txt (line 40)) (65.5.0)
# Requirement already satisfied: wheel in /home/tom/projects/KI/.env/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->-r ../requirements.txt (line 40)) (0.40.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## Preprocessing of the data
# This part prepares the data for the model and learning process.
#
# ### Load and understand the dataset
# The data are loaded and a histogram of the data is created to understand the data and how they correlate to each other.

# %%
DATA_PATH = "../data/"

original_data = pd.read_csv(DATA_PATH + "student-por_2.csv", sep=";")
original_data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     MS   M   16       R     GT3       T     1     1  at_home     other
# 1     MS   F   18       R     GT3       T     2     2    other     other
# 2     MS   M   17       R     GT3       T     1     1    other  services
# 3     GP   M   18       U     LE3       T     1     1    other     other
# 4     GP   F   18       U     GT3       T     2     1    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0   other   father           2          1         0        no     no   no
# 1   other   mother           2          1         1        no     no   no
# 2  course   mother           2          1         0        no    yes   no
# 3  course   mother           1          1         2        no     no   no
# 4    home   mother           1          2         0        no    yes   no
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# 0        yes     yes    yes       no       no       3         4      4     3
# 1         no     yes     no      yes      yes       5         5      5     1
# 2        yes      no    yes      yes      yes       4         5      5     1
# 3         no     yes     no      yes      yes       2         3      5     2
# 4         no     yes    yes      yes      yes       4         2      5     1
#
#    Walc  health  absences  G1  G2  G3  Unnamed: 33
# 0     4       5         6  11  11  11  0,581558765
# 1     1       3         0   8   6   0  0,677773943
# 2     3       2         0  10   9  10   0,58860641
# 3     5       4         0  11   9   0  0,627079796
# 4     2       1         8  14  14  15  0,459968853

# %%
original_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 34 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   school       599 non-null    object
#  1   sex          599 non-null    object
#  2   age          599 non-null    int64
#  3   address      599 non-null    object
#  4   famsize      599 non-null    object
#  5   Pstatus      599 non-null    object
#  6   Medu         599 non-null    int64
#  7   Fedu         599 non-null    int64
#  8   Mjob         599 non-null    object
#  9   Fjob         599 non-null    object
#  10  reason       599 non-null    object
#  11  guardian     599 non-null    object
#  12  traveltime   599 non-null    int64
#  13  studytime    599 non-null    int64
#  14  failures     599 non-null    int64
#  15  schoolsup    599 non-null    object
#  16  famsup       599 non-null    object
#  17  paid         599 non-null    object
#  18  activities   599 non-null    object
#  19  nursery      599 non-null    object
#  20  higher       599 non-null    object
#  21  internet     599 non-null    object
#  22  romantic     599 non-null    object
#  23  famrel       599 non-null    int64
#  24  freetime     599 non-null    int64
#  25  goout        599 non-null    int64
#  26  Dalc         599 non-null    int64
#  27  Walc         599 non-null    int64
#  28  health       599 non-null    int64
#  29  absences     599 non-null    int64
#  30  G1           599 non-null    int64
#  31  G2           599 non-null    int64
#  32  G3           599 non-null    int64
#  33  Unnamed: 33  599 non-null    object
# dtypes: int64(16), object(18)
# memory usage: 159.2+ KB

# %% [markdown]
# ### Check for false values and counts

# %%
with open(DATA_PATH + "values_counts.txt", "w") as f:
    for col in original_data.columns:
        unique_values = original_data[col].sort_values().unique()
        value_counts = original_data[col].value_counts()
        f.write(f"{col}: {unique_values} \n{value_counts}\n")
        f.write("-"*50)
        f.write("\n\n")

# %%
original_data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    16.752922    2.489149    2.287145    1.564274    1.944908    0.230384
# std      1.234558    1.135973    1.093161    0.748773    0.823141    0.601290
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean     3.949917    3.183639    3.168614    1.489149    2.258765    3.545910
# std      0.945414    1.048809    1.169548    0.906756    1.279430    1.443755
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    2.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  599.000000  599.000000  599.000000  599.000000
# mean     3.597663   11.414023   11.562604   11.909850
# std      4.590239    2.754541    2.922466    3.267129
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   10.000000   10.000000   10.000000
# 50%      2.000000   11.000000   11.000000   12.000000
# 75%      6.000000   13.000000   13.000000   14.000000
# max     32.000000   19.000000   19.000000   19.000000

# %% [markdown]
# ## Create numerical scales

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer

data = original_data.copy()

# Delete the columns that are not useful
del data['Unnamed: 33']

# Binary columns to be converted to 0/1
data['school'] = data['school'].map({'GP': 0, 'MS': 1})
data['sex'] = data['sex'].map({'F': 0, 'M': 1})
data['address'] = data['address'].map({'U': 0, 'R': 1})
data['famsize'] = data['famsize'].map({'LE3': 0, 'GT3': 1})
data['Pstatus'] = data['Pstatus'].map({'T': 0, 'A': 1})
data['schoolsup'] = data['schoolsup'].map({'yes': 1, 'no': 0})
data['famsup'] = data['famsup'].map({'yes': 1, 'no': 0})
data['paid'] = data['paid'].map({'yes': 1, 'no': 0})
data['activities'] = data['activities'].map({'yes': 1, 'no': 0})
data['nursery'] = data['nursery'].map({'yes': 1, 'no': 0})
data['higher'] = data['higher'].map({'yes': 1, 'no': 0})
data['internet'] = data['internet'].map({'yes': 1, 'no': 0})
data['romantic'] = data['romantic'].map({'yes': 1, 'no': 0})

# Categories to be converted to one-hot encoding
converter = make_column_transformer((OneHotEncoder(), [
    # 'school',
    # 'sex',
    # 'address',
    'Mjob',
    'Fjob',
    'reason',
    'guardian',
    # 'traveltime',
    # 'studytime',
]), remainder='passthrough', verbose_feature_names_out=False)
converted = converter.fit_transform(data)
converted = pd.DataFrame(converted, columns=converter.get_feature_names_out())

# Remove label prefixes

converted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 46 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Mjob_at_home       599 non-null    float64
#  1   Mjob_health        599 non-null    float64
#  2   Mjob_other         599 non-null    float64
#  3   Mjob_services      599 non-null    float64
#  4   Mjob_teacher       599 non-null    float64
#  5   Fjob_at_home       599 non-null    float64
#  6   Fjob_health        599 non-null    float64
#  7   Fjob_other         599 non-null    float64
#  8   Fjob_services      599 non-null    float64
#  9   Fjob_teacher       599 non-null    float64
#  10  reason_course      599 non-null    float64
#  11  reason_home        599 non-null    float64
#  12  reason_other       599 non-null    float64
#  13  reason_reputation  599 non-null    float64
#  14  guardian_father    599 non-null    float64
#  15  guardian_mother    599 non-null    float64
#  16  guardian_other     599 non-null    float64
#  17  school             599 non-null    float64
#  18  sex                599 non-null    float64
#  19  age                599 non-null    float64
#  20  address            599 non-null    float64
#  21  famsize            599 non-null    float64
#  22  Pstatus            599 non-null    float64
#  23  Medu               599 non-null    float64
#  24  Fedu               599 non-null    float64
#  25  traveltime         599 non-null    float64
#  26  studytime          599 non-null    float64
#  27  failures           599 non-null    float64
#  28  schoolsup          599 non-null    float64
#  29  famsup             599 non-null    float64
#  30  paid               599 non-null    float64
#  31  activities         599 non-null    float64
#  32  nursery            599 non-null    float64
#  33  higher             599 non-null    float64
#  34  internet           599 non-null    float64
#  35  romantic           599 non-null    float64
#  36  famrel             599 non-null    float64
#  37  freetime           599 non-null    float64
#  38  goout              599 non-null    float64
#  39  Dalc               599 non-null    float64
#  40  Walc               599 non-null    float64
#  41  health             599 non-null    float64
#  42  absences           599 non-null    float64
#  43  G1                 599 non-null    float64
#  44  G2                 599 non-null    float64
#  45  G3                 599 non-null    float64
# dtypes: float64(46)
# memory usage: 215.4 KB

# %%
converted.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_2ec6d_row0_col0, #T_2ec6d_row1_col1, #T_2ec6d_row2_col2, #T_2ec6d_row3_col3, #T_2ec6d_row4_col4, #T_2ec6d_row5_col5, #T_2ec6d_row6_col6, #T_2ec6d_row7_col7, #T_2ec6d_row8_col8, #T_2ec6d_row9_col9, #T_2ec6d_row10_col10, #T_2ec6d_row11_col11, #T_2ec6d_row12_col12, #T_2ec6d_row13_col13, #T_2ec6d_row14_col14, #T_2ec6d_row15_col15, #T_2ec6d_row16_col16, #T_2ec6d_row17_col17, #T_2ec6d_row18_col18, #T_2ec6d_row19_col19, #T_2ec6d_row20_col20, #T_2ec6d_row21_col21, #T_2ec6d_row22_col22, #T_2ec6d_row23_col23, #T_2ec6d_row24_col24, #T_2ec6d_row25_col25, #T_2ec6d_row26_col26, #T_2ec6d_row27_col27, #T_2ec6d_row28_col28, #T_2ec6d_row29_col29, #T_2ec6d_row30_col30,
_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_eada4_row0_col1" class="data row0 col1" >0.609985</td>
#       <td id="T_eada4_row0_col2" class="data row0 col2" >-0.186606</td>
#     </tr>
#     <tr>
#       <th id="T_eada4_level0_row1" class="row_heading level0 row1" >Walc</th>
#       <td id="T_eada4_row1_col0" class="data row1 col0" >0.609985</td>
#       <td id="T_eada4_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_eada4_row1_col2" class="data row1 col2" >-0.162832</td>
#     </tr>
#     <tr>
#       <th id="T_eada4_level0_row2" class="row_heading level0 row2" >G3</th>
#       <td id="T_eada4_row2_col0" class="data row2 col0" >-0.186606</td>
#       <td id="T_eada4_row2_col1" class="data row2 col1" >-0.162832</td>
#       <td id="T_eada4_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Create Network

# %%
import bnlearn as bn

structure_data = converted.copy()
# del structure_data['Unnamed: 33']


model = bn.structure_learning.fit(structure_data, methodtype='tan', root_node="age", class_node='G3')
# Compute edge strength using chi-square independence test and remove (prune) the not-signficant edges
model = bn.independence_test(model, structure_data, alpha=0.05, prune=True)
print(model['independence_test'])

# %%
bn.plot(model)
# Out:
# [bnlearn] >Set node properties.
# [bnlearn]> Set edge weights based on the [chi_square] test statistic.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model
# {'fig': <Figure size 1500x1000 with 1 Axes>,
#  'ax': <Figure size 1500x1000 with 1 Axes>,
#  'pos': {'Mjob_at_home': array([-0.48360084, -0.06801266]),
#   'Mjob_health': array([-0.08314676,  0.26104413]),
#   'Mjob_other': array([-0.49778119,  0.26909863]),
#   'Mjob_services': array([-0.672809  ,  0.60652663]),
#   'Mjob_teacher': array([-0.54739849,  0.43447799]),
#   'Fjob_at_home': array([ 0.73985391, -0.07066448]),
#   'Fjob_health': array([ 0.77960542, -0.09063119]),
#   'Fjob_other': array([ 0.65369432, -0.0419531 ]),
#   'Fjob_services': array([ 0.99341657, -0.10521076]),
#   'Fjob_teacher': array([0.28334942, 0.03873418]),
#   'reason_course': array([-0.14043058, -0.38960366]),
#   'reason_home': array([-0.34641677, -0.38748529]),
#   'reason_other': array([-0.26403864, -0.2678221 ]),
#   'reason_reputation': array([ 0.10070736, -0.47811469]),
#   'guardian_father': array([0.25987655, 0.49223824]),
#   'guardian_mother': array([0.1650842 , 0.91711323]),
#   'guardian_other': array([-0.0576418 ,  0.14676928]),
#   'school': array([ 0.16047964, -0.18131166]),
#   'sex': array([0.24514861, 0.20137615]),
#   'age': array([0.00098318, 0.14307581]),
#   'address': array([-0.29422693, -0.36930733]),
#   'famsize': array([-0.21410157,  0.8292182 ]),
#   'Pstatus': array([-0.15893301,  0.81264579]),
#   'Medu': array([-0.37085637,  0.20619683]),
#   'Fedu': array([-0.42926242,  0.18346368]),
#   'traveltime': array([-0.74930328, -0.55425402]),
#   'studytime': array([ 0.96832454, -0.39507366]),
#   'failures': array([ 0.31627419, -0.69483367]),
#   'schoolsup': array([1.        , 0.14800624]),
#   'famsup': array([-0.480172  ,  0.79685911]),
#   'paid': array([-0.13709322, -0.84364583]),
#   'activities': array([ 0.63409096, -0.82393301]),
#   'nursery': array([-0.22362653,  0.91770849]),
#   'higher': array([ 0.26111104, -0.68754544]),
#   'internet': array([-0.68038627, -0.5101346 ]),
#   'romantic': array([-0.87734576,  0.14242192]),
#   'famrel': array([-0.83720358, -0.18273862]),
#   'freetime': array([-0.19710504,  0.27954193]),
#   'goout': array([-0.28020096,  0.3121322 ]),
#   'Dalc': array([-0.76153749,  0.29522504]),
#   'Walc': array([-0.25866186,  0.24721708]),
#   'health': array([-0.43222432, -0.80630011]),
#   'absences': array([ 0.72965775, -0.59667161]),
#   'G1': array([ 0.28668912, -0.82175793]),
#   'G2': array([0.97346171, 0.32610904]),
#   'G3': array([0.92369623, 0.35980563])},
#  'G': <networkx.classes.digraph.DiGraph at 0x7f0905c7b0a0>,
#  'node_properties': {'Mjob_at_home': {'node_color': '#1f456e',
#    'node_size': 800},
#   'Mjob_health': {'node_color': '#1f456e', 'node_size': 800},
#   'Mjob_other': {'node_color': '#1f456e', 'node_size': 800},
#   'Mjob_services': {'node_color': '#1f456e', 'node_size': 800},
#   'Mjob_teacher': {'node_color': '#1f456e', 'node_size': 800},
#   'Fjob_at_home': {'node_color': '#1f456e', 'node_size': 800},
#   'Fjob_health': {'node_color': '#1f456e', 'node_size': 800},
#   'Fjob_other': {'node_color': '#1f456e', 'node_size': 800},
#   'Fjob_services': {'node_color': '#1f456e', 'node_size': 800},
#   'Fjob_teacher': {'node_color': '#1f456e', 'node_size': 800},
#   'reason_course': {'node_color': '#1f456e', 'node_size': 800},
#   'reason_home': {'node_color': '#1f456e', 'node_size': 800},
#   'reason_other': {'node_color': '#1f456e', 'node_size': 800},
#   'reason_reputation': {'node_color': '#1f456e', 'node_size': 800},
#   'guardian_father': {'node_color': '#1f456e', 'node_size': 800},
#   'guardian_mother': {'node_color': '#1f456e', 'node_size': 800},
#   'guardian_other': {'node_color': '#1f456e', 'node_size': 800},
#   'school': {'node_color': '#1f456e', 'node_size': 800},
#   'sex': {'node_color': '#1f456e', 'node_size': 800},
#   'age': {'node_color': '#1f456e', 'node_size': 800},
#   'address': {'node_color': '#1f456e', 'node_size': 800},
#   'famsize': {'node_color': '#1f456e', 'node_size': 800},
#   'Pstatus': {'node_color': '#1f456e', 'node_size': 800},
#   'Medu': {'node_color': '#1f456e', 'node_size': 800},
#   'Fedu': {'node_color': '#1f456e', 'node_size': 800},
#   'traveltime': {'node_color': '#1f456e', 'node_size': 800},
#   'studytime': {'node_color': '#1f456e', 'node_size': 800},
#   'failures': {'node_color': '#1f456e', 'node_size': 800},
#   'schoolsup': {'node_color': '#1f456e', 'node_size': 800},
#   'famsup': {'node_color': '#1f456e', 'node_size': 800},
#   'paid': {'node_color': '#1f456e', 'node_size': 800},
#   'activities': {'node_color': '#1f456e', 'node_size': 800},
#   'nursery': {'node_color': '#1f456e', 'node_size': 800},
#   'higher': {'node_color': '#1f456e', 'node_size': 800},
#   'internet': {'node_color': '#1f456e', 'node_size': 800},
#   'romantic': {'node_color': '#1f456e', 'node_size': 800},
#   'famrel': {'node_color': '#1f456e', 'node_size': 800},
#   'freetime': {'node_color': '#1f456e', 'node_size': 800},
#   'goout': {'node_color': '#1f456e', 'node_size': 800},
#   'Dalc': {'node_color': '#1f456e', 'node_size': 800},
#   'Walc': {'node_color': '#1f456e', 'node_size': 800},
#   'health': {'node_color': '#1f456e', 'node_size': 800},
#   'absences': {'node_color': '#1f456e', 'node_size': 800},
#   'G1': {'node_color': '#1f456e', 'node_size': 800},
#   'G2': {'node_color': '#1f456e', 'node_size': 800},
#   'G3': {'node_color': '#1f456e', 'node_size': 800}},
#  'edge_properties': {('Fedu', 'Medu'): {'color': '#000000',
#    'weight': 7.572580740601436},
#   ('Fjob_at_home', 'Fjob_services'): {'color': '#000000',
#    'weight': 1.2422830597630212},
#   ('Fjob_health', 'Fjob_services'): {'color': '#000000',
#    'weight': 1.0431889391152829},
#   ('Fjob_other', 'Fjob_at_home'): {'color': '#000000',
#    'weight': 2.0879640644036126},
#   ('Fjob_other', 'Fjob_health'): {'color': '#000000',
#    'weight': 1.4535577733691656},
#   ('Fjob_other', 'Fjob_services'): {'color': '#000000',
#    'weight': 7.447331180525309},
#   ('Fjob_other', 'Fjob_teacher'): {'color': '#000000',
#    'weight': 1.8300626890319203},
#   ('Fjob_teacher', 'Fedu'): {'color': '#000000', 'weight': 3.329146475492479},
#   ('Fjob_teacher', 'Fjob_services'): {'color': '#000000',
#    'weight': 1.162097271682889},
#   ('Medu', 'Mjob_at_home'): {'color': '#000000', 'weight': 2.6773192901574507},
#   ('Medu', 'Mjob_health'): {'color': '#000000', 'weight': 1.9610613824489858},
#   ('Medu', 'Mjob_teacher'): {'color': '#000000', 'weight': 4.75920267380538},
#   ('Mjob_at_home', 'Mjob_services'): {'color': '#000000',
#    'weight': 1.8321054431577686},
#   ('Mjob_at_home', 'address'): {'color': '#000000',
#    'weight': 1.2715266904431104},
#   ('Mjob_at_home', 'internet'): {'color': '#000000',
#    'weight': 1.6524189605298691},
#   ('Mjob_at_home', 'reason_course'): {'color': '#000000',
#    'weight': 1.1264723129826852},
#   ('Mjob_health', 'Fjob_health'): {'color': '#000000',
#    'weight': 1.5202262442820182},
#   ('Mjob_health', 'Mjob_other'): {'color': '#000000',
#    'weight': 1.539048520054462},
#   ('Mjob_health', 'Mjob_services'): {'color': '#000000',
#    'weight': 1.1550430836865937},
#   ('Mjob_health', 'Mjob_teacher'): {'color': '#000000', 'weight': 1.0},
#   ('Mjob_other', 'Mjob_at_home'): {'color': '#000000',
#    'weight': 3.1128009559055716},
#   ('Mjob_other', 'Mjob_services'): {'color': '#000000',
#    'weight': 3.1128009559055716},
#   ('Mjob_teacher', 'Mjob_other'): {'color': '#000000',
#    'weight': 1.9469716456528234},
#   ('Mjob_teacher', 'Mjob_services'): {'color': '#000000',
#    'weight': 1.332335563470303},
#   ('Pstatus', 'famsize'): {'color': '#000000', 'weight': 1.648787547260003},
#   ('Walc', 'Dalc'): {'color': '#000000', 'weight': 8.228738710015348},
#   ('Walc', 'sex'): {'color': '#000000', 'weight': 2.1151331892210092},
#   ('address', 'school'): {'color': '#000000', 'weight': 2.732530172573429},
#   ('address', 'traveltime'): {'color': '#000000', 'weight': 2.414124984073953},
#   ('failures', 'higher'): {'color': '#000000', 'weight': 2.1691241949669693},
#   ('famsize', 'nursery'): {'color': '#000000', 'weight': 1.0289264178516015},
#   ('goout', 'Walc'): {'color': '#000000', 'weight': 2.763384962487856},
#   ('guardian_father', 'Fjob_other'): {'color': '#000000',
#    'weight': 1.1345879886608101},
#   ('guardian_father', 'Pstatus'): {'color': '#000000',
#    'weight': 1.2422624956496238},
#   ('guardian_father', 'guardian_mother'): {'color': '#000000', 'weight': 10.0},
#   ('guardian_other', 'failures'): {'color': '#000000',
#    'weight': 1.8464948183131495},
#   ('guardian_other', 'guardian_father'): {'color': '#000000',
#    'weight': 1.1557744093064963},
#   ('guardian_other', 'guardian_mother'): {'color': '#000000',
#    'weight': 3.053473673864114},
#   ('guardian_other', 'romantic'): {'color': '#000000',
#    'weight': 1.1549270700554952},
#   ('higher', 'G1'): {'color': '#000000', 'weight': 2.480551366619027},
#   ('reason_course', 'reason_home'): {'color': '#000000',
#    'weight': 3.8919040296705285},
#   ('reason_course', 'reason_other'): {'color': '#000000',
#    'weight': 2.179671637706647},
#   ('reason_course', 'reason_reputation'): {'color': '#000000',
#    'weight': 3.8346172004559023},
#   ('reason_home', 'address'): {'color': '#000000',
#    'weight': 1.2376377041519442},
#   ('reason_other', 'reason_home'): {'color': '#000000',
#    'weight': 1.3484898462775963},
#   ('reason_reputation', 'activities'): {'color': '#000000',
#    'weight': 1.1585400265353203},
#   ('reason_reputation', 'reason_home'): {'color': '#000000',
#    'weight': 1.9502094097685296},
#   ('reason_reputation', 'reason_other'): {'color': '#000000',
#    'weight': 1.3394366781669578},
#   ('reason_reputation', 'school'): {'color': '#000000',
#    'weight': 1.2303999647751585},
#   ('school', 'internet'): {'color': '#000000', 'weight': 1.7380150108056576},
#   ('school', 'schoolsup'): {'color': '#000000', 'weight': 1.0611903229638004},
#   ('sex', 'famsup'): {'color': '#000000', 'weight': 1.085005184611144},
#   ('sex', 'studytime'): {'color': '#000000', 'weight': 1.6492061491592755},
#   ('G3', 'G2'): {'color': '#000000', 'weight': 10.0},
#   ('age', 'guardian_other'): {'color': '#000000', 'weight': 4.181853135486192},
#   ('freetime', 'goout'): {'color': '#000000', 'weight': 2.7633834882117827}}}

# %%
from pgmpy.factors.discrete.CPD import TabularCPD

# Create CPDs
cpds = network.get_cpds()

for cpd in cpds:
    print(cpd)

# %%
test_data = pd.read_csv(DATA_PATH + "student-por_3.csv", sep=";")
test_data = test_data.loc[[i for i in range(0, 100)]]

del test_data['Unnamed: 33']

label = test_data['G3']
del test_data['G3']
del test_data['G2']

# Predict
results = network.predict(test_data, stochastic=False)

for i in range(len(results)):
    print(f"Predicted: {results.loc[i, 'G3']}, Actual: {label[i]}")

# %% [markdown]
# ## Evaluation

# %%
def distance(a, b):
    return abs(a - b)

def accuracy(results, label):
    correct = 0
    for i in range(len(results)):
        if distance(results.loc[i, 'G3'], label[i]) <= 1:
            correct += 1
    return correct / len(results)

def average_error(results, label):
    error = 0
    for i in range(len(results)):
        error += distance(results.loc[i, 'G3'], label[i])
    return error / len(results)

def average_error_without_match(results, label):
    error = 0
    count = 0
    for i in range(len(results)):
        if distance(results.loc[i, 'G3'], label[i]) > 1:
            error += distance(results.loc[i, 'G3'], label[i])
            count += 1
    return error / count

ac = accuracy(results, label)
av_err = average_error(results, label)
av_err_without = average_error_without_match(results, label)
print(f"Accuracy: {ac}, Average Error: {av_err}, Average Error Without Match: {av_err_without}")
