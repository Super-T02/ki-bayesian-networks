# %% [markdown]
# # Probabilistic Network for the grades of Portugiese students

# %%
# !python -m venv ../.env
# !source ../.env/bin/activate
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: aiohttp==3.8.4 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 1)) (3.8.4)
# Requirement already satisfied: aiosignal==1.3.1 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: asttokens==2.2.1 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 3)) (2.2.1)
# Requirement already satisfied: async-timeout==4.0.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 4)) (4.0.2)
# Requirement already satisfied: attrs==22.2.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 5)) (22.2.0)
# Requirement already satisfied: backcall==0.2.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.12.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 7)) (4.12.0)
# Requirement already satisfied: bleach==6.0.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 8)) (6.0.0)
# Requirement already satisfied: bnlearn==0.7.14 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 9)) (0.7.14)
# Requirement already satisfied: certifi==2022.12.7 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 10)) (2022.12.7)
# Requirement already satisfied: charset-normalizer==3.1.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 11)) (3.1.0)
# Requirement already satisfied: click==8.1.3 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 12)) (8.1.3)
# Requirement already satisfied: cmake==3.26.1 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 13)) (3.26.1)
# Requirement already satisfied: comm==0.1.3 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 14)) (0.1.3)
# Requirement already satisfied: contourpy==1.0.7 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 15)) (1.0.7)
# Requirement already satisfied: cycler==0.11.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 16)) (0.11.0)
# Requirement already satisfied: dataframe-image==0.1.9 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 17)) (0.1.9)
# Requirement already satisfied: debugpy==1.6.6 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 18)) (1.6.6)
# Requirement already satisfied: decorator==5.1.1 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 19)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 20)) (0.7.1)
# Requirement already satisfied: df2onehot==1.0.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 21)) (1.0.2)
# Requirement already satisfied: et-xmlfile==1.1.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 22)) (1.1.0)
# Requirement already satisfied: executing==1.2.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 23)) (1.2.0)
# Requirement already satisfied: fastjsonschema==2.16.3 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 24)) (2.16.3)
# Requirement already satisfied: filelock==3.10.7 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 25)) (3.10.7)
# Requirement already satisfied: fonttools==4.39.3 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 26)) (4.39.3)
# Requirement already satisfied: frozenlist==1.3.3 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 27)) (1.3.3)
# Requirement already satisfied: fsspec==2023.3.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 28)) (2023.3.0)
# Requirement already satisfied: funcsigs==1.0.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 29)) (1.0.2)
# Requirement already satisfied: graphviz==0.20.1 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 30)) (0.20.1)
# Requirement already satisfied: idna==3.4 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 31)) (3.4)
# Requirement already satisfied: intel-openmp==2023.1.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 32)) (2023.1.0)
# Requirement already satisfied: ipykernel==6.22.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 33)) (6.22.0)
# Requirement already satisfied: ipython==8.12.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 34)) (8.12.0)
# Requirement already satisfied: ipywidgets==8.0.6 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 35)) (8.0.6)
# Requirement already satisfied: ismember==1.0.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 36)) (1.0.2)
# Requirement already satisfied: jedi==0.18.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 37)) (0.18.2)
# Requirement already satisfied: Jinja2==3.1.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 38)) (3.1.2)
# Requirement already satisfied: joblib==1.2.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 39)) (1.2.0)
# Requirement already satisfied: jsonpickle==3.0.1 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 40)) (3.0.1)
# Requirement already satisfied: jsonschema==4.17.3 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 41)) (4.17.3)
# Requirement already satisfied: jupyter_client==8.1.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 42)) (8.1.0)
# Requirement already satisfied: jupyter_core==5.3.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 43)) (5.3.0)
# Requirement already satisfied: jupyterlab-pygments==0.2.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 44)) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets==3.0.7 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 45)) (3.0.7)
# Requirement already satisfied: kiwisolver==1.4.4 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 46)) (1.4.4)
# Requirement already satisfied: lit==16.0.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 47)) (16.0.0)
# Requirement already satisfied: MarkupSafe==2.1.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 48)) (2.1.2)
# Requirement already satisfied: matplotlib==3.7.1 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 49)) (3.7.1)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 50)) (0.1.6)
# Requirement already satisfied: mistune==2.0.5 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 51)) (2.0.5)
# Requirement already satisfied: mkl==2023.1.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 52)) (2023.1.0)
# Requirement already satisfied: mpmath==1.3.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 53)) (1.3.0)
# Requirement already satisfied: multidict==6.0.4 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 54)) (6.0.4)
# Requirement already satisfied: nbclient==0.7.3 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 55)) (0.7.3)
# Requirement already satisfied: nbconvert==7.2.10 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 56)) (7.2.10)
# Requirement already satisfied: nbformat==5.8.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 57)) (5.8.0)
# Requirement already satisfied: nest-asyncio==1.5.6 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 58)) (1.5.6)
# Requirement already satisfied: networkx==3.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 59)) (3.0)
# Requirement already satisfied: numpy==1.24.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 60)) (1.24.2)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 61)) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 62)) (11.7.101)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 63)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 64)) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 65)) (8.5.0.96)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 66)) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 67)) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 68)) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 69)) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 70)) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 71)) (11.7.91)
# Requirement already satisfied: openpyxl==3.1.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 72)) (3.1.2)
# Requirement already satisfied: opt-einsum==3.3.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 73)) (3.3.0)
# Requirement already satisfied: packaging==23.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 74)) (23.0)
# Requirement already satisfied: pandas==1.5.3 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 75)) (1.5.3)
# Requirement already satisfied: pandocfilters==1.5.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 76)) (1.5.0)
# Requirement already satisfied: parso==0.8.3 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 77)) (0.8.3)
# Requirement already satisfied: patsy==0.5.3 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 78)) (0.5.3)
# Requirement already satisfied: pexpect==4.8.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 79)) (4.8.0)
# Requirement already satisfied: pgmpy==0.1.21 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 80)) (0.1.21)
# Requirement already satisfied: pickleshare==0.7.5 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 81)) (0.7.5)
# Requirement already satisfied: Pillow==9.5.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 82)) (9.5.0)
# Requirement already satisfied: platformdirs==3.2.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 83)) (3.2.0)
# Requirement already satisfied: prompt-toolkit==3.0.38 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 84)) (3.0.38)
# Requirement already satisfied: psutil==5.9.4 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 85)) (5.9.4)
# Requirement already satisfied: ptyprocess==0.7.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 86)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 87)) (0.2.2)
# Requirement already satisfied: Pygments==2.14.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 88)) (2.14.0)
# Requirement already satisfied: pyparsing==3.0.9 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 89)) (3.0.9)
# Requirement already satisfied: pypickle==1.1.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 90)) (1.1.0)
# Requirement already satisfied: pyrsistent==0.19.3 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 91)) (0.19.3)
# Requirement already satisfied: python-dateutil==2.8.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 92)) (2.8.2)
# Requirement already satisfied: python-louvain==0.16 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 93)) (0.16)
# Requirement already satisfied: pytz==2023.3 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 94)) (2023.3)
# Requirement already satisfied: pyvis==0.3.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 95)) (0.3.2)
# Requirement already satisfied: pyzmq==25.0.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 96)) (25.0.2)
# Requirement already satisfied: requests==2.28.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 97)) (2.28.2)
# Requirement already satisfied: scikit-learn==1.2.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 98)) (1.2.2)
# Requirement already satisfied: scipy==1.10.1 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 99)) (1.10.1)
# Requirement already satisfied: seaborn==0.12.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 100)) (0.12.2)
# Requirement already satisfied: six==1.16.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 101)) (1.16.0)
# Requirement already satisfied: soupsieve==2.4 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 102)) (2.4)
# Requirement already satisfied: stack-data==0.6.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 103)) (0.6.2)
# Requirement already satisfied: statsmodels==0.13.5 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 104)) (0.13.5)
# Requirement already satisfied: sympy==1.11.1 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 105)) (1.11.1)
# Requirement already satisfied: tabulate==0.9.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 106)) (0.9.0)
# Requirement already satisfied: tbb==2021.9.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 107)) (2021.9.0)
# Requirement already satisfied: threadpoolctl==3.1.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 108)) (3.1.0)
# Requirement already satisfied: tinycss2==1.2.1 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 109)) (1.2.1)
# Requirement already satisfied: tk==0.1.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 110)) (0.1.0)
# Requirement already satisfied: torch==2.0.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 111)) (2.0.0)
# Requirement already satisfied: tornado==6.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 112)) (6.2)
# Requirement already satisfied: tqdm==4.65.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 113)) (4.65.0)
# Requirement already satisfied: traitlets==5.9.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 114)) (5.9.0)
# Requirement already satisfied: triton==2.0.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 115)) (2.0.0)
# Requirement already satisfied: typing_extensions==4.5.0 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 116)) (4.5.0)
# Requirement already satisfied: urllib3==1.26.15 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 117)) (1.26.15)
# Requirement already satisfied: wcwidth==0.2.6 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 118)) (0.2.6)
# Requirement already satisfied: webencodings==0.5.1 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 119)) (0.5.1)
# Requirement already satisfied: wget==3.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 120)) (3.2)
# Requirement already satisfied: widgetsnbextension==4.0.7 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 121)) (4.0.7)
# Requirement already satisfied: yarl==1.8.2 in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from -r ../requirements.txt (line 122)) (1.8.2)
# Requirement already satisfied: wheel in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->-r ../requirements.txt (line 61)) (0.40.0)
# Requirement already satisfied: setuptools in /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->-r ../requirements.txt (line 61)) (65.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %reset -f
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import dataframe_image as dfi
import networkx as nx
from   framework import Framework
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
pd.set_option('display.max_columns', 500)

# Constants
DATA_PATH = "../data/"
DOC_PATH = "../doc/"

# %% [markdown]
# ## Preprocessing of the data
# This part prepares the data for the model and learning process.
#
# ### Load and understand the dataset
# The data are loaded and a histogram of the data is created to understand the data and how they correlate to each other.

# %%
original_data = pd.read_csv(DATA_PATH + "student-por_2.csv", sep=";")
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     MS   M   16       R     GT3       T     1     1  at_home     other
# 1     MS   F   18       R     GT3       T     2     2    other     other
# 2     MS   M   17       R     GT3       T     1     1    other  services
# 3     GP   M   18       U     LE3       T     1     1    other     other
# 4     GP   F   18       U     GT3       T     2     1    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0   other   father           2          1         0        no     no   no
# 1   other   mother           2          1         1        no     no   no
# 2  course   mother           2          1         0        no    yes   no
# 3  course   mother           1          1         2        no     no   no
# 4    home   mother           1          2         0        no    yes   no
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# 0        yes     yes    yes       no       no       3         4      4     3
# 1         no     yes     no      yes      yes       5         5      5     1
# 2        yes      no    yes      yes      yes       4         5      5     1
# 3         no     yes     no      yes      yes       2         3      5     2
# 4         no     yes    yes      yes      yes       4         2      5     1
#
#    Walc  health  absences  G1  G2  G3  Unnamed: 33
# 0     4       5         6  11  11  11  0,581558765
# 1     1       3         0   8   6   0  0,677773943
# 2     3       2         0  10   9  10   0,58860641
# 3     5       4         0  11   9   0  0,627079796
# 4     2       1         8  14  14  15  0,459968853

# %%
original_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 34 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   school       599 non-null    object
#  1   sex          599 non-null    object
#  2   age          599 non-null    int64
#  3   address      599 non-null    object
#  4   famsize      599 non-null    object
#  5   Pstatus      599 non-null    object
#  6   Medu         599 non-null    int64
#  7   Fedu         599 non-null    int64
#  8   Mjob         599 non-null    object
#  9   Fjob         599 non-null    object
#  10  reason       599 non-null    object
#  11  guardian     599 non-null    object
#  12  traveltime   599 non-null    int64
#  13  studytime    599 non-null    int64
#  14  failures     599 non-null    int64
#  15  schoolsup    599 non-null    object
#  16  famsup       599 non-null    object
#  17  paid         599 non-null    object
#  18  activities   599 non-null    object
#  19  nursery      599 non-null    object
#  20  higher       599 non-null    object
#  21  internet     599 non-null    object
#  22  romantic     599 non-null    object
#  23  famrel       599 non-null    int64
#  24  freetime     599 non-null    int64
#  25  goout        599 non-null    int64
#  26  Dalc         599 non-null    int64
#  27  Walc         599 non-null    int64
#  28  health       599 non-null    int64
#  29  absences     599 non-null    int64
#  30  G1           599 non-null    int64
#  31  G2           599 non-null    int64
#  32  G3           599 non-null    int64
#  33  Unnamed: 33  599 non-null    object
# dtypes: int64(16), object(18)
# memory usage: 159.2+ KB

# %% [markdown]
# ### Check for false values and counts

# %%
with open(DATA_PATH + "values_counts.txt", "w") as f:
    for col in original_data.columns:
        unique_values = original_data[col].sort_values().unique()
        value_counts = original_data[col].value_counts()
        f.write(f"{col}: {unique_values} \n{value_counts}\n")
        f.write("-"*50)
        f.write("\n\n")

# %%
original_data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    16.752922    2.489149    2.287145    1.564274    1.944908    0.230384
# std      1.234558    1.135973    1.093161    0.748773    0.823141    0.601290
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean     3.949917    3.183639    3.168614    1.489149    2.258765    3.545910
# std      0.945414    1.048809    1.169548    0.906756    1.279430    1.443755
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    2.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  599.000000  599.000000  599.000000  599.000000
# mean     3.597663   11.414023   11.562604   11.909850
# std      4.590239    2.754541    2.922466    3.267129
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   10.000000   10.000000   10.000000
# 50%      2.000000   11.000000   11.000000   12.000000
# 75%      6.000000   13.000000   13.000000   14.000000
# max     32.000000   19.000000   19.000000   19.000000

# %% [markdown]
# ## Create numerical scales

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer

data = original_data.copy()

# Delete the columns that are not useful
del data['Unnamed: 33']

# Binary columns to be converted to 0/1
data['school'] = data['school'].map({'GP': 0, 'MS': 1})
data['sex'] = data['sex'].map({'F': 0, 'M': 1})
data['address'] = data['address'].map({'U': 0, 'R': 1})
data['famsize'] = data['famsize'].map({'LE3': 0, 'GT3': 1})
data['Pstatus'] = data['Pstatus'].map({'T': 0, 'A': 1})
data['schoolsup'] = data['schoolsup'].map({'yes': 1, 'no': 0})
data['famsup'] = data['famsup'].map({'yes': 1, 'no': 0})
data['paid'] = data['paid'].map({'yes': 1, 'no': 0})
data['activities'] = data['activities'].map({'yes': 1, 'no': 0})
data['nursery'] = data['nursery'].map({'yes': 1, 'no': 0})
data['higher'] = data['higher'].map({'yes': 1, 'no': 0})
data['internet'] = data['internet'].map({'yes': 1, 'no': 0})
data['romantic'] = data['romantic'].map({'yes': 1, 'no': 0})

# Categories to be converted to one-hot encoding
converter = make_column_transformer((OneHotEncoder(), [
    # 'school',
    # 'sex',
    # 'address',
    'Mjob',
    'Fjob',
    'reason',
    'guardian',
    'G3'
    # 'traveltime',
    # 'studytime',
]), remainder='passthrough', verbose_feature_names_out=False)
converted = converter.fit_transform(data)
converted = pd.DataFrame(converted, columns=converter.get_feature_names_out())

# Delete the columns that are not useful
converted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 62 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Mjob_at_home       599 non-null    float64
#  1   Mjob_health        599 non-null    float64
#  2   Mjob_other         599 non-null    float64
#  3   Mjob_services      599 non-null    float64
#  4   Mjob_teacher       599 non-null    float64
#  5   Fjob_at_home       599 non-null    float64
#  6   Fjob_health        599 non-null    float64
#  7   Fjob_other         599 non-null    float64
#  8   Fjob_services      599 non-null    float64
#  9   Fjob_teacher       599 non-null    float64
#  10  reason_course      599 non-null    float64
#  11  reason_home        599 non-null    float64
#  12  reason_other       599 non-null    float64
#  13  reason_reputation  599 non-null    float64
#  14  guardian_father    599 non-null    float64
#  15  guardian_mother    599 non-null    float64
#  16  guardian_other     599 non-null    float64
#  17  G3_0               599 non-null    float64
#  18  G3_1               599 non-null    float64
#  19  G3_5               599 non-null    float64
#  20  G3_6               599 non-null    float64
#  21  G3_7               599 non-null    float64
#  22  G3_8               599 non-null    float64
#  23  G3_9               599 non-null    float64
#  24  G3_10              599 non-null    float64
#  25  G3_11              599 non-null    float64
#  26  G3_12              599 non-null    float64
#  27  G3_13              599 non-null    float64
#  28  G3_14              599 non-null    float64
#  29  G3_15              599 non-null    float64
#  30  G3_16              599 non-null    float64
#  31  G3_17              599 non-null    float64
#  32  G3_18              599 non-null    float64
#  33  G3_19              599 non-null    float64
#  34  school             599 non-null    float64
#  35  sex                599 non-null    float64
#  36  age                599 non-null    float64
#  37  address            599 non-null    float64
#  38  famsize            599 non-null    float64
#  39  Pstatus            599 non-null    float64
#  40  Medu               599 non-null    float64
#  41  Fedu               599 non-null    float64
#  42  traveltime         599 non-null    float64
#  43  studytime          599 non-null    float64
#  44  failures           599 non-null    float64
#  45  schoolsup          599 non-null    float64
#  46  famsup             599 non-null    float64
#  47  paid               599 non-null    float64
#  48  activities         599 non-null    float64
#  49  nursery            599 non-null    float64
#  50  higher             599 non-null    float64
#  51  internet           599 non-null    float64
#  52  romantic           599 non-null    float64
#  53  famrel             599 non-null    float64
#  54  freetime           599 non-null    float64
#  55  goout              599 non-null    float64
#  56  Dalc               599 non-null    float64
#  57  Walc               599 non-null    float64
#  58  health             599 non-null    float64
#  59  absences           599 non-null    float64
#  60  G1                 599 non-null    float64
#  61  G2                 599 non-null    float64
# dtypes: float64(62)
# memory usage: 290.3 KB

# %%
corr_styled = converted.corr().style.background_gradient(cmap='RdYlGn', axis=None).set_precision(2)
# dfi.export(corr_styled, DOC_PATH + "correlation_matrix.png", max_cols=-1)
corr_styled.to_excel(DOC_PATH + "correlation_matrix.xlsx")
# Out:
# /tmp/ipykernel_3383/1120182488.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr_styled = converted.corr().style.background_gradient(cmap='RdYlGn', axis=None).set_precision(2)

# %% [markdown]
# ## Create Network

# %%
from pgmpy.models import BayesianNetwork
from pgmpy.estimators import BayesianEstimator

model_data = original_data.copy()
del model_data['Unnamed: 33']

# Create Network
network = BayesianNetwork()

# Add all columns as nodes
for col in model_data.columns:
    network.add_node(col)
    
# Add edges
edges = [
    ("G1", "G3"),
    ("G2", "G3"),  
    ("Walc", "G1"),
    ("Dalc", "G1"),
    ("school", "G1"),
    ("studytime", "G1"),
    ("higher", "G1"),
    ("failures", "G1"),
    # ("Fedu", "G1"),
    # ("Medu", "G1"),
    ("Walc", "G2"),
    ("Dalc", "G2"),
    ("school", "G2"),
    ("studytime", "G2"),
    ("higher", "G2"),
    ("failures", "G2"),
    ("Fedu", "G2"),
    ("Medu", "G2"),
    
    ("sex", "Walc"),
    ("sex", "Dalc"),
    ("sex", "studytime"),
    
    ("reason", "school"),
    
    ("address", "school"),
    ("address", "internet"),
    
    ("age", "higher"),
    ("age", "guardian"),
    ("age", "failures"),
    
    # ("school", "internet"),
    # ("Medu", "internet"),
    # ("Fedu", "internet"),
    ("internet", "G1"),
    ("internet", "G2"),
    
    
    ("traveltime", "G1"),
    ("traveltime", "G2"),
    
    ("freetime", "G1"),
    ("freetime", "G2"),
    
    ("absences", "G1"),
    ("absences", "G2"),
    
    ("Fjob", "G1"),
    ("Fjob", "G2"),
    ("Mjob", "G1"),
    ("Mjob", "G2"),
    ("Medu", "Mjob"),
    ("Fedu", "Fjob"),
    
    
]

Framework.add_edges(network, edges)

# Draw network
Framework.draw_model(network)


# Fit data
network.fit(model_data, n_jobs=10)

# %%
test_data = pd.read_csv(DATA_PATH + "student-por_3.csv", sep=";")
# test_data = test_data.loc[[i for i in range(0, 100)]]

del test_data['Unnamed: 33']

label = test_data['G3']
del test_data['G3']
del test_data['G2']
del test_data['G1']

# Predict
results = network.predict(test_data, stochastic=False, n_jobs=10)
# Out:
#   0%|          | 0/599 [00:00<?, ?it/s]

# %%
results.to_csv(DATA_PATH + "results.csv", index=False)
label.to_csv(DATA_PATH + "label.csv", index=False)

# %% [markdown]
# ## Evaluation

# %%
results = pd.read_csv(DATA_PATH + "results.csv")
label = pd.read_csv(DATA_PATH + "label.csv")

# %%
from evaluation import Evaluation

evaluation = Evaluation(label, results.loc[:, 'G3'])
evaluation.print_stats()
evaluation.plot()
# Out:
# Accuracy: 0.4340567612687813
# Mean absolute error: 1.6026711185308848
# Precision: 0.4481927218268993
# Recall: 0.3768337189318694
# F1 score: 0.3652490457901757
# /home/tom/projects/probability-ki/.env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
